# %% [markdown]
# ## Machine Learning Assignment # 1
#
#
# Hey Guys,
#
# This is your first assignment in Machine Learning.We'll focus on Linear regression alongwith gradient descent.

# %% [markdown]
# **Q1**. What is gradient descent algorithm? What is its function?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Gradient descent is a first-order iterative optimization algorithm for finding the minimum of a function. To find a local minimum of a function using gradient descent, one takes steps proportional to the negative of the gradient (or approximate gradient) of the function at the current point. If, instead, one takes steps proportional to the positive of the gradient, one approaches a local maximum of that function; the procedure is then known as gradient ascent. Gradient descent was originally proposed by Cauchy in 1847.
#
# Gradient descent is also known as steepest descent.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Q2.** Teach your computer to approximate the given function using linear regression and gradient descent.
#
# f(x) = 17x + 29

# %%
# sample code
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# generate random data-set
np.random.seed(0)
x = np.random.rand(100, 1)
y = 2 + 3 * x + np.random.rand(100, 1)

# sckit-learn implementation

# Model initialization
regression_model = LinearRegression()
# Fit the data(train the model)
regression_model.fit(x, y)
# Predict
y_predicted = regression_model.predict(x)

# model evaluation
mse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

# printing values
print('Coefficients:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('mean squared error: ', mse)
print('R2 score: ', r2)

# plotting values

# data points
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')

# predicted values
plt.plot(x, y_predicted, color='r')
plt.show()
# Out:
# Coefficients: [[2.93655106]]
# Intercept: [2.55808002]
# mean squared error:  0.07623324582875007
# R2 score:  0.9038655568672764

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# generate random data-set
np.random.seed(0)
x = np.random.rand(100, 1)
y = 17 * x + 29

# sckit-learn implementation

# Model initialization
regression_model = LinearRegression()
# Fit the data(train the model)
regression_model.fit(x, y)
# Predict
y_predicted = regression_model.predict(x)

# model evaluation
mse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

# printing values
print('Coefficients:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('mean squared error: ', mse)
print('R2 score: ', r2)

# plotting values

# data points
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')

# predicted values
plt.plot(x, y_predicted, color='r')
plt.show()
# Out:
# Coefficients: [[17.]]
# Intercept: [29.]
# mean squared error:  2.0321056918493265e-29
# R2 score:  1.0

# %% [markdown]
# **Q3.** Utilize sklearn Linear Regression functionality and solve the following problem:
#
#
# *  Load the boston housing data from the scikit-learn library. Read about it in this link : https://www.kaggle.com/c/boston-housing
#
# *   Run linear regression with four features of your choice and optimize the code for low MSE error
#
# *   Construct a non-linear hypothesis and run polynomial regression

# %%
import pandas as pd
df = pd.read_csv("housing.csv")

# %%
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
df.columns
# Out:
# Index(['RM', 'LSTAT', 'PTRATIO', 'MEDV'], dtype='object')

# %%
y = df['MEDV']

# %%
y.head()
# Out:
# 0    504000.0
# 1    453600.0
# 2    728700.0
# 3    701400.0
# 4    760200.0
# Name: MEDV, dtype: float64

# %%
x = df.iloc[:,:-1 ]

# %%
from sklearn.model_selection import train_test_split

# %%
trainX,testX,trainY,testY =train_test_split(x,y)

# %%
regression_model = LinearRegression()

# %%
trainX.shape
# Out:
# (366, 3)

# %%
trainY.shape
# Out:
# (366,)

# %%
regression_model.fit(trainX,trainY)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predict
y_predicted = regression_model.predict(testX)

# %% [markdown]
# y_pre= y_predicted.round(1)
# y_pre

# %%
y_predicted.shape
# Out:
# (123,)

# %%
# model evaluation
mse = mean_squared_error(testY,y_predicted)
r2 = r2_score(testY, y_predicted)

# %%
# printing values
print('Coefficients:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('mean squared error: ', mse)
print('R2 score: ', r2)
# Out:
# Coefficients: [ 80072.84576902 -10598.5636136  -19007.92797742]
# Intercept: 443391.0603525594
# mean squared error:  7242967013.530384
# R2 score:  0.777492559170304

# %%
trainX.shape
# Out:
# (366, 3)

# %%
trainY.shape
# Out:
# (366,)

# %%
# plotting values

# data points
plt.scatter(testY, y_predicted)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()
# predicted values
plt.plot(testX["RM"],  y_predicted, color='r',label='RM')
plt.plot(testX["LSTAT"],  y_predicted, color='g',label='LSTAT')
plt.plot(testX["PTRATIO"],  y_predicted, color='b',label='PTRATIO')
plt.xlabel("True Values of x1,x2 and x3")
plt.ylabel("Predictions")

plt.show()

# %% [markdown]
# **Q4**   Here are the links for sample codes as well :
#
# 1.  https://colab.research.google.com/drive/1LVRBw48Gu1B255SkmlM8T1baIIfuCGS8
#
# 2. https://colab.research.google.com/drive/1jK2GYCKiJwhHwKnfNoxOAaRQWY9a4280
#
# 3. https://colab.research.google.com/drive/1tSpBoEn2phIZxxv4GDaDE2zwJRc18EkT

# %% [markdown]
# Optimize the code by tuning the Hyperparameters: Alpha, iterations, intial hypothesis design and data preprocessing.
