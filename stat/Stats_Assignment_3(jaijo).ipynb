# %% [markdown]
# ## Statistics Assignment # 3
#
# Hey guys,
#
# Lets check your understanding with statistical inference.
#
# Try either coding/writing them in colab itself or write them down on notebook and upload the pics.
#
# Send /share them with amritansh.48@gmail.com

# %% [markdown]
# **Q1.**  What is p-value. What's its significance in Hypothesis testing?

# %% [markdown]
# p-value
#
# -Is the level of marginal significance within a statistical hypothesis test representing the probability of the occurrence of a given event. The p-value is used as an alternative to rejection points to provide the smallest level of significance at which the null hypothesis would be rejected.
#
# significance in Hypothesis testing
# Hypothesis testing is used to infer the result of a hypothesis performed on sample data from a larger population. The test tells the analyst whether or not his primary hypothesis is true.

# %% [markdown]
# **Q2.** In a factory, the weight of the concrete poured into a mold by a machine follows a normal distribution with a mean of 1150 pounds and a standard deviation of 22 pounds. Approximately 95% of molds filled by this machine will hold weights in what interval? What about 99%?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Mu +/- STd = 1128 to 1172
#
# for 95%
#
# CI = Mu +/- 2*STd = 1106 to 1194
#
# for 99%
#
# CI = Mu +/- 3*STd = 1084 to 1216

# %% [markdown]
# **Q3.** Women’s heights have a mean of 63.6 in. and a standard deviation of 2.5 inches.  The z score corresponding to a woman with a height is 2.56. How tall is the woman?

# %% [markdown]
# ![image.png](attachment:image.png)
# :-Given
#
# Z = 2.56
#
# Mu= 63.6
#
# Std= 2.5
#
# x = Z(std) +Mu = 2.56(2.5) + 63.6
#
#   = 70 inch

# %% [markdown]
# **Q4.** The mean temperature in Glens Falls for the month of February is 23 degrees with a standard deviation of 4.2 degrees.  What is the z-score for a temperature of 17 degrees?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# :-Given
#
# x =17
#
# Mu =23
#
# Std =4.2
#
# Z = -1.43

# %% [markdown]
# **Q5.** For a Christmas and New Year’s week, the
# National Safety Council estimated that 500 people
# would be killed and 25,000 injured on the nation’s
# roads.  The NSC claimed that 50% of the accidents
# would be caused by drunk driving.
# A sample of 120 accidents showed that 67 were
# caused by drunk driving.  Use these data to test the
# NSC’s claim with alpha = .05

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Q6**. What purpose does hypothesis testing serves? What is the idea of testing hypthesis using level of significance. How is p-value approach different?

# %% [markdown]
# *What pupose does hypothesis testing serves? Ans:-Hypothesis testing is used to infer the result of a hypothesis performed on sample data from a larger population. The test tells the analyst whether or not his primary hypothesis is true. Statistical analysts test a hypothesis by measuring and examining a random sample of the population being analyzed.
#
# *What is the idea of testing hypthesis using level of significance. Ans:-The concept of statistical significance is fundamental to hypothesis testing. In a study that involves drawing a random sample from a larger population in an effort to prove some result that can be applied to the population as a whole, there is the constant potential for the study data to be a result of sampling error or simple coincidence or chance. By determining a significance level and testing the p-value against it, a researcher can confidently uphold or reject the null hypothesis. The significance level, in the simplest of terms, is the threshold probability of incorrectly rejecting the null hypothesis when it is in fact true. This is also known as the type I error rate. The significance level or alpha is therefore associated with the overall confidence level of the test, meaning that the higher the value of alpha, the greater the confidence in the test
#
# *Type I Errors and Level of Significance A type I error, or an error of the first kind, occurs when the null hypothesis is rejected when in reality it is true. In other words, a type I error is comparable to a false positive. Type I errors are controlled by defining an appropriate level of significance. Best practice in scientific hypothesis testing calls for selecting a significance level before data collection even begins. The most common significance level is 0.05 (or 5%) which means that there is a 5% probability that the test will suffer a type I error by rejecting a true null hypothesis. This significance level conversely translates to a 95% level of confidence, meaning that over a series of hypothesis tests, 95% will not result in a type I error
#
# *How is p-value approach different? The p-value is used as an alternative to rejection points to provide the smallest level of significance at which the null hypothesis would be rejected. A smaller p-value means that there is stronger evidence in favor of the alternative hypothesis

# %% [markdown]
# **Q7**. The population size is 340. The population exhibits a normal distribution.
# A sample of size n = 76 was taken;  Now the average mean for this sample is 79.9. Std deviation is 5.6.
#
#
#
# Find the Confidence Interval when Confidence Coefficient is 0.9, 0.95 and 0.99

# %% [markdown]
# CI =
# ![image.png](attachment:image.png)

# %% [markdown]
# **Q8**.  We have a sample distribution of different varities of apples. We pick a random sample from local superstore. The sample mean is Rs. 130 per kg. Std deviation is rs. 14.
# Let us provide a 90% confidence interval estimate of the mean price per kg for the population. We will assume this population to be normally distributed. Find out the range of error.

# %% [markdown]
# ![image.png](attachment:image.png)
